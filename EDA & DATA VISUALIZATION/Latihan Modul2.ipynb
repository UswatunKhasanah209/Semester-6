# %%
#Latihan 1
import pandas as pd

sales_data = pd.read_csv('sales_data.csv')
sales_data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  PRODUCTLINE PRODUCTCODE              CUSTOMERNAME
# 0   2/24/2003 0:00  Shipped  Motorcycles    S10_1678         Land of Toys Inc.
# 1    5/7/2003 0:00  Shipped  Motorcycles    S10_1678        Reims Collectables
# 2    7/1/2003 0:00  Shipped  Motorcycles    S10_1678           Lyon Souveniers
# 3   8/25/2003 0:00  Shipped  Motorcycles    S10_1678         Toys4GrownUps.com
# 4  10/10/2003 0:00  Shipped  Motorcycles    S10_1678  Corporate Gift Ideas Co.

# %%
#Latihan 2
import pandas as pd

sales_data = pd.read_csv('sales_data.csv')

print("a. 5 baris pertama dari dataset:")
print(sales_data.head())
print("\nb. Informasi dasar dataset:")
print(sales_data.info())
# Out:
# a. 5 baris pertama dari dataset:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  PRODUCTLINE PRODUCTCODE              CUSTOMERNAME
# 0   2/24/2003 0:00  Shipped  Motorcycles    S10_1678         Land of Toys Inc.
# 1    5/7/2003 0:00  Shipped  Motorcycles    S10_1678        Reims Collectables
# 2    7/1/2003 0:00  Shipped  Motorcycles    S10_1678           Lyon Souveniers
# 3   8/25/2003 0:00  Shipped  Motorcycles    S10_1678         Toys4GrownUps.com
# 4  10/10/2003 0:00  Shipped  Motorcycles    S10_1678  Corporate Gift Ideas Co.
#
# b. Informasi dasar dataset:
# ...

# %%
#Latihan 3

import pandas as pd

sales_data = pd.read_csv('sales_data.csv')

Penjumlahan= sales_data['SALES'].sum()
print("Total unit terjual:", Penjumlahan)

Rata_rata = sales_data['SALES'].mean()
print("Rata-rata unit terjual per transaksi:", Rata_rata)

rt = sales_data['QUANTITYORDERED'].mean()
print(round(rt/sales_data['ORDERLINENUMBER']))
# Out:
# Total unit terjual: 10032628.85
# Rata-rata unit terjual per transaksi: 3553.889071909316
# 0       18.0
# 1        7.0
# 2       18.0
# 3        6.0
# 4        3.0
#         ...
# 2818     2.0
# 2819    35.0
# 2820     9.0
# 2821    35.0
# 2822     4.0
# Name: ORDERLINENUMBER, Length: 2823, dtype: float64
